# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-db0155065c7a> in <module>()
#       8 x00 = np.random.random (10)
#       9 x0=x00*3
# ---> 10 y0 = sin (2*x0)
#      11
#      12 plt.plot(x0, y0, 'o', label='Data')
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


 x = np.linspace(0, 3)
y = sin (2*x)

plt.plot(x0, y0, 'o', label='Data')



options = ('linear', 'quadratic', 'cubic')

for o in options:
    f = interp1d(x0, y0, kind=o)    # interpolation function
    plt.plot(x, f(x), label=o)      # plot of interpolated data

plt.legend()
plt.show()
# Out:
#   File "<ipython-input-26-fd246117976f>", line 6
#     x = np.linspace(0, 3)
#     ^
# IndentationError: unexpected indent

# %%
 x = np.linspace(0, 10, num=11, endpoint=True)
 y = np.cos(-x**2/9.0)
f = interp1d(x, y)
 f2 = interp1d(x, y, kind='cubic')


 xnew = np.linspace(0, 10, num=41, endpoint=True)
import matplotlib.pyplot as plt
plt.plot(x, y, 'o', xnew, f(xnew), '-', xnew, f2(xnew), '--')
plt.legend(['data', 'linear', 'cubic'], loc='best')
plt.show()

# %%
 x = np.linspace(0, 3, num=10, endpoint=True)
y = sin (2*x)

plt.plot(x0, y0, 'o', label='Data')
# Out:
#   File "<ipython-input-24-a2c29f3d0464>", line 2
#     x = np.linspace(0, 3, num=10, endpoint=True)
#     ^
# IndentationError: unexpected indent

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


x0 = np.random.random(10)
x = (x0*20)-10

y = np.sin(x)/x

plt.plot(x, y, 'o', label='Data')


xp = np.linspace(min(x), max(x), 51051)
                
  
options = ('linear', 'quadratic', 'cubic')
for o in options:
    f = interp1d(x, y, kind=o)    
    plt.plot(xp, f(xp), label=o)    
    
plt.legend([ 'linear', 'quadratic', 'cubic'], loc='best')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


x0 = np.random.random(10)
x = (x0*16)-10

y = np.sin(x)/x

plt.plot(x, y, 'o', label='Data')


x = np.linspace(-3,3,10)
  
options = ('linear', 'quadratic', 'cubic')
for o in options:
    f = interp1d(x, y, kind=o)    
    plt.plot(xp, f(xp), label=o)    
    
plt.legend([ 'linear', 'quadratic', 'cubic'], loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-7d7a51b90750> in <module>()
#      17 for o in options:
#      18     f = interp1d(x, y, kind=o)
# ---> 19     plt.plot(xp, f(xp), label=o)
#      20
#      21 plt.legend([ 'linear', 'quadratic', 'cubic'], loc='best')
#
# /usr/lib/python2.7/dist-packages/scipy/interpolate/polyint.pyc in __call__(self, x)
#      77         """
#      78         x, x_shape = self._prepare_x(x)
# ---> 79         y = self._evaluate(x)
#      80         return self._finish_y(y, x_shape)
#      81
#
# /usr/lib/python2.7/dist-packages/scipy/interpolate/interpolate.pyc in _evaluate(self, x_new)
#     475         #    The behavior is set by the bounds_error variable.
#     476         x_new = asarray(x_new)
# --> 477         out_of_bounds = self._check_bounds(x_new)
#     478         y_new = self._call(self, x_new)
#     479         if len(y_new) > 0:
#
# /usr/lib/python2.7/dist-packages/scipy/interpolate/interpolate.pyc in _check_bounds(self, x_new)
#     502         # !! Could provide more information about which values are out of bounds
#     503         if self.bounds_error and below_bounds.any():
# --> 504             raise ValueError("A value in x_new is below the interpolation "
#     505                 "range.")
#     506         if self.bounds_error and above_bounds.any():
#
# ValueError: A value in x_new is below the interpolation range.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


x0 = np.random.random(10)
x = (x0*20)-10

y = np.sin(x)/x

plt.plot(x, y, 'o', label='Data')


xp = np.linspace(min(x), max(x), 51051)
                
  
options = ('linear', 'quadratic', 'cubic')
for o in options:
    f = interp1d(x, y, kind=o)    
    plt.plot(xp, f(xp), label=o)    
    
plt.legend([ 'linear', 'quadratic', 'cubic'], loc='best')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


x0 = np.random.random(12)
x = (x0*4)-2

y = (x**3)*np.sin(2*x)



plt.plot(x, y, 'o', label='Data')


xp = np.linspace(min(x), max(x), 5100)
                
  
options = ('linear', 'quadratic', 'cubic')
for o in options:
    f = interp1d(x, y, kind=o)    
    plt.plot(xp, f(xp), label=o)    
    
plt.legend([ 'linear', 'quadratic', 'cubic'], loc='best')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


x0 = np.random.random(16)
x = (x0*6)-3

y = (x**2)*np.sin(2*x)



plt.plot(x, y, 'o', label='Data')


xp = np.linspace(min(x), max(x), 5100)
                
  
options = ('linear', 'quadratic', 'cubic')
for o in options:
    f = interp1d(x, y, kind=o)    
    plt.plot(xp, f(xp), label=o)    
    
plt.legend([ 'linear', 'quadratic', 'cubic'], loc='best')
plt.show()
